# %%
# %%capture
# !pip install requests
# !pip install beautifulsoup4
# !pip install cloudscraper
# !pip install selenium
# !pip install webdriver-manager
# !pip install undetected-chromedriver

# %%
import time
import requests
import cloudscraper
scraper = cloudscraper.create_scraper()
import pandas as pd
from bs4 import BeautifulSoup
from io import StringIO
# Selenium imports (try undetected_chromedriver first)
try:
    import undetected_chromedriver as uc
    _HAS_UC = True
except Exception:
    _HAS_UC = False
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
def get_with_selenium(url, wait=3, headless=True):
    if _HAS_UC:
        try:
            options = uc.ChromeOptions()
            if headless:
                options.headless = True
            options.add_argument('--disable-gpu')
            options.add_argument('--no-sandbox')
            options.add_argument('--disable-dev-shm-usage')
            driver = uc.Chrome(options=options)
            driver.get(url)
            time.sleep(wait)
            html = driver.page_source
            driver.quit()
            return type('R', (), {'text': html, 'status_code': 200})()
        except Exception:
            pass
    # Fallback: webdriver + webdriver_manager
    options = Options()
    if headless:
        options.add_argument('--headless=new')
    options.add_argument('--disable-gpu')
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=options)
    driver.get(url)
    time.sleep(wait)
    html = driver.page_source
    driver.quit()
    return type('R', (), {'text': html, 'status_code': 200})()

# %%
url = "https://fbref.com/en/comps/9/Premier-League-Stats"
headers = { 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36' }
data = get_with_selenium(url, wait=4)
time.sleep(1)

# %%
soup = BeautifulSoup(data.text, 'html.parser')

# %%
tables = soup.select('table.stats_table')
if tables:
    stats_table = tables[0]
else:
    print("No se encontró 'table.stats_table'. Buscando enlaces alternativos...")
    stats_table = None
# Out:
# No se encontró 'table.stats_table'. Buscando enlaces alternativos...

# %%
# Diagnóstico: revisar el response y el HTML recibido
print('response status code:', getattr(data, 'status_code', None))
html_snippet = data.text[:1000].replace('\n', ' ')
print('HTML snippet:', html_snippet[:800])
if stats_table is not None:
    links = stats_table.find_all('a')
else:
    links = soup.find_all('a')
links = [l.get("href") for l in links if l]
print('Total links encontrados:', len(links))
print('Primeros 20 enlaces:', links[:20])
links = [l for l in links if '/squads/' in l]
# Out:
# response status code: 200
# HTML snippet: <html lang="en-US" dir="ltr"><head><title>Un momento…</title><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="robots" content="noindex,nofollow"><meta name="viewport" content="width=device-width,initial-scale=1"><meta http-equiv="content-security-policy" content="default-src 'none'; script-src 'nonce-GA2LxqZHyYPyM8Eq19ytpx' 'unsafe-eval' https://challenges.cloudflare.com; script-src-attr 'none'; style-src 'unsafe-inline'; img-src 'self' https://challenges.cloudflare.com; connect-src 'self' https://challenges.cloudflare.com; frame-src 'self' https://challenges.cloudflare.com blob:; child-src 'self' https://challenges.cloudflare.com blob:; worker-src blob:; form-action http: https:; base-uri 'self'"><style>*{b
# Total links encontrados: 2
# Primeros 20 enlaces: ['https://www.cloudflare.com?utm_source=challenge&utm_campaign=l', 'https://www.cloudflare.com/es-es/privacypolicy/']

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
data = get_with_selenium(team_urls[0], wait=3)
html_buffer = StringIO(data.text)
matches = pd.read_html(html_buffer, match="Scores & Fixtures")[0]
matches.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 data = requests.get(team_urls[0])
#       2 html_buffer = StringIO(data.text)
#       3 matches = pd.read_html(html_buffer, match="Scores & Fixtures")[0]
#
# IndexError: list index out of range

# %%
# el tag c9 trae los datos de la Premier League

soup = BeautifulSoup(html_buffer)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'c9/schedule/' in l]

# %%
#Fixture completo de las 38 fechas jugadas en la temporada 2023/2024

data = get_with_selenium(f"https://fbref.com{links[0]}", wait=3)
man_city_premier_stats = pd.read_html(data.text, match="Scores & Fixtures")[0]
man_city_premier_stats.head()
time.sleep(1)
# Out:
# C:\Windows\Temp\ipykernel_18416\3071462477.py:4: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   man_city_premier_stats = pd.read_html(data.text, match="Scores & Fixtures")[0]

# %%
man_city_premier_stats = man_city_premier_stats.drop(columns=['Match Report'])

# %%
man_city_premier_stats = man_city_premier_stats.drop(columns=['Notes'])

# %%
man_city_premier_stats.set_index('Round', inplace=True)

# %%
man_city_premier_stats.to_csv('matches.csv')

# %%
#Scrapeo Tabla de Tiros del Man.City
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'c9/shooting/' in l]

# %%
data = get_with_selenium(f"https://fbref.com{links[0]}", wait=3)
shooting = pd.read_html(data.text, match="Shooting")[0]
time.sleep(1)
# Out:
# C:\Windows\Temp\ipykernel_18416\1615510361.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]

# %%
shooting.columns = shooting.columns.droplevel()

# %%
shooting.set_index('Round', inplace=True)

# %%
shooting.columns
# Out:
# Index(['Date', 'Time', 'Day', 'Venue', 'Result', 'GF', 'GA', 'Opponent', 'Gls',
#        'Sh', 'SoT', 'SoT%', 'G/Sh', 'G/SoT', 'Dist', 'FK', 'PK', 'PKatt', 'xG',
#        'npxG', 'npxG/Sh', 'G-xG', 'np:G-xG'],
#       dtype='object')

# %%
columns_to_drop = ['Date', 'Time', 'Day', 'Venue', 'Result', 'GF', 'GA', 'Opponent','Match Report']
shooting.drop(columns= columns_to_drop, inplace=True)

# %%
shooting.head()
# Out:
#              Gls  Sh  SoT  SoT%  G/Sh  G/SoT  Dist  FK  PK  PKatt   xG  npxG  \
# Round
# Matchweek 1    3  17    8  47.1  0.18   0.38  13.9   0   0      0  1.9   1.9
# Matchweek 2    1  14    4  28.6  0.07   0.25  17.9   0   0      0  1.0   1.0
# Matchweek 3    2  29    9  31.0  0.07   0.22  17.3   2   0      1  3.5   2.8
# Matchweek 4    5   6    4  66.7  0.67   1.00  14.8   0   1      1  2.2   1.4
# Matchweek 5    3  29   13  44.8  0.10   0.23  16.4   1   0      0  3.6   3.6
#
#              npxG/Sh  G-xG  np:G-xG
# Round
# Matchweek 1     0.12   1.1      1.1
# Matchweek 2     0.07   0.0      0.0
# Matchweek 3     0.10  -1.5     -0.8
# Matchweek 4     0.25   2.8      2.6
# Matchweek 5     0.13  -0.6     -0.6

# %%
#Scrapeo Tabla de Goles y Creación de Tiros del Man.City
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'c9/gca/' in l]

# %%
data = get_with_selenium(f"https://fbref.com{links[0]}", wait=3)
gca = pd.read_html(data.text, match="Goal and Shot Creation")[0]
time.sleep(1)
# Out:
# C:\Windows\Temp\ipykernel_18416\3695685396.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   gca = pd.read_html(data.text, match="Goal and Shot Creation")[0]

# %%
gca.columns = gca.columns.droplevel()
gca = gca.drop(columns=['Match Report'])

# %%
# Establecer "Round" como el índice
gca.set_index('Round', inplace=True)

# %%
# Nuevos nombres de las columnas
new_column_names = [
    'Date', 'Time', 'Day', 'Venue', 'Result', 'GF', 'GA', 'Opponent', 'SCA',
    'sca_PassLive', 'sca_PassDead', 'sca_TO', 'sca_Sh', 'sca_Fld', 'sca_Def', 
    'GCA', 'gca_PassLive', 'gca_PassDead', 'gca_TO', 'gca_Sh', 'gca_Fld', 'gca_Def'
]

# Asignar los nuevos nombres de las columnas utilizando la ubicación por índice
gca.columns = new_column_names

# %%
gca.columns
# Out:
# Index(['Date', 'Time', 'Day', 'Venue', 'Result', 'GF', 'GA', 'Opponent', 'SCA',
#        'sca_PassLive', 'sca_PassDead', 'sca_TO', 'sca_Sh', 'sca_Fld',
#        'sca_Def', 'GCA', 'gca_PassLive', 'gca_PassDead', 'gca_TO', 'gca_Sh',
#        'gca_Fld', 'gca_Def'],
#       dtype='object')

# %%
gca.drop(columns= columns_to_drop, inplace=True)

# %%
gca.head()
# Out:
#              SCA  sca_PassLive  sca_PassDead  sca_TO  sca_Sh  sca_Fld  \
# Round
# Matchweek 1   29            20             3       1       2        3
# Matchweek 2   27            24             1       1       1        0
# Matchweek 3   58            52             1       1       2        2
# Matchweek 4   13             9             1       1       1        1
# Matchweek 5   55            45             1       2       5        1
#
#              sca_Def  GCA  gca_PassLive  gca_PassDead  gca_TO  gca_Sh  \
# Round
# Matchweek 1        0    5             4             0       0       1
# Matchweek 2        0    2             2             0       0       0
# Matchweek 3        0    4             3             0       0       1
# Matchweek 4        0    9             5             1       1       1
# Matchweek 5        1    6             6             0       0       0
#
#              gca_Fld  gca_Def
# Round
# Matchweek 1        0        0
# Matchweek 2        0        0
# Matchweek 3        0        0
# Matchweek 4        1        0
# Matchweek 5        0        0

# %%
offensive_stats = pd.merge(shooting, gca, on='Round', how='inner')

# %%
offensive_stats.head()
# Out:
#              Gls  Sh  SoT  SoT%  G/Sh  G/SoT  Dist  FK  PK  PKatt  ...  \
# Round                                                              ...
# Matchweek 1    3  17    8  47.1  0.18   0.38  13.9   0   0      0  ...
# Matchweek 2    1  14    4  28.6  0.07   0.25  17.9   0   0      0  ...
# Matchweek 3    2  29    9  31.0  0.07   0.22  17.3   2   0      1  ...
# Matchweek 4    5   6    4  66.7  0.67   1.00  14.8   0   1      1  ...
# Matchweek 5    3  29   13  44.8  0.10   0.23  16.4   1   0      0  ...
#
#              sca_Sh  sca_Fld  sca_Def  GCA  gca_PassLive  gca_PassDead  \
# Round
# Matchweek 1       2        3        0    5             4             0
# Matchweek 2       1        0        0    2             2             0
# Matchweek 3       2        2        0    4             3             0
# Matchweek 4       1        1        0    9             5             1
# Matchweek 5       5        1        1    6             6             0
#
#              gca_TO  gca_Sh  gca_Fld  gca_Def
# Round
# Matchweek 1       0       1        0        0
# Matchweek 2       0       0        0        0
# Matchweek 3       0       1        0        0
# Matchweek 4       1       1        1        0
# Matchweek 5       0       0        0        0
#
# [5 rows x 29 columns]

# %%
offensive_stats.to_csv("shooting_stats.csv")

# %%
#Scrapeo Tabla de Pases del Man.City
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'c9/passing/' in l]

# %%
data = get_with_selenium(f"https://fbref.com{links[0]}", wait=3)
passing = pd.read_html(data.text, match="Passing")[0]
time.sleep(1)
# Out:
# C:\Windows\Temp\ipykernel_18416\1354743369.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   passing = pd.read_html(data.text, match="Passing")[0]

# %%
# Renombrar las columnas especificas
passing_new_columns = []
for col in passing.columns:
    if col[1] in ['Cmp', 'Att', 'Cmp%']:
        passing_new_columns.append((col[0], f"{col[0]}_{col[1]}"))
    else:
        passing_new_columns.append(col)

# %%
passing.columns = passing.columns.from_tuples(passing_new_columns)

# %%
passing.columns = passing.columns.droplevel()

# %%
columns_to_drop = ['Date', 'Time', 'Day', 'Venue', 'Result', 'GF', 'GA', 'Opponent','Match Report']

# %%
passing.drop(columns= columns_to_drop, inplace=True)

# %%
passing.columns
# Out:
# Index(['Round', 'Total_Cmp', 'Total_Att', 'Total_Cmp%', 'TotDist', 'PrgDist',
#        'Short_Cmp', 'Short_Att', 'Short_Cmp%', 'Medium_Cmp', 'Medium_Att',
#        'Medium_Cmp%', 'Long_Cmp', 'Long_Att', 'Long_Cmp%', 'Ast', 'xAG', 'xA',
#        'KP', '1/3', 'PPA', 'CrsPA', 'PrgP'],
#       dtype='object')

# %%
# Establecer "Round" como el índice
passing.set_index('Round', inplace=True)

# %%
passing.head()
# Out:
#              Total_Cmp  Total_Att  Total_Cmp%  TotDist  PrgDist  Short_Cmp  \
# Round
# Matchweek 1        655        740        88.5    10790     3194        325
# Matchweek 2        632        714        88.5    10155     2989        343
# Matchweek 3        707        793        89.2    12243     3342        311
# Matchweek 4        681        766        88.9    11763     3078        305
# Matchweek 5        676        747        90.5    10979     2860        337
#
#              Short_Att  Short_Cmp%  Medium_Cmp  Medium_Att  ...  Long_Att  \
# Round                                                       ...
# Matchweek 1        339        95.9         252         277  ...        84
# Matchweek 2        366        93.7         234         263  ...        58
# Matchweek 3        326        95.4         326         352  ...        81
# Matchweek 4        329        92.7         288         311  ...        90
# Matchweek 5        359        93.9         280         301  ...        63
#
#              Long_Cmp%  Ast  xAG   xA  KP  1/3  PPA  CrsPA  PrgP
# Round
# Matchweek 1       60.7    2  1.3  1.3  14   42   10      2    28
# Matchweek 2       65.5    1  1.0  0.8  13   29    7      0    42
# Matchweek 3       67.9    2  2.5  2.7  25   50   23      3    75
# Matchweek 4       72.2    3  0.9  0.6   5   39    8      1    38
# Matchweek 5       74.6    3  3.3  3.5  24   60   18      3    75
#
# [5 rows x 22 columns]

# %%
#Scrapeo Tabla de Tipos de Pases del Man.City
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'c9/passing_types/' in l]

# %%
data = get_with_selenium(f"https://fbref.com{links[0]}", wait=3)
pass_types = pd.read_html(data.text, match="Pass Types")[0]
time.sleep(1)
# Out:
# C:\Windows\Temp\ipykernel_18416\1095874312.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pass_types = pd.read_html(data.text, match="Pass Types")[0]

# %%
pass_types.columns = pass_types.columns.droplevel()

# %%
columns_to_drop = ['Date', 'Time', 'Day', 'Venue', 'Result', 'GF', 'GA', 'Opponent','Match Report']

# %%
pass_types = pass_types.drop(columns=columns_to_drop)

# %%
pass_types = pass_types.drop(columns=['Match Report'])

# %%
pass_types.columns
# Out:
# Index(['Att', 'Live', 'Dead', 'FK', 'TB', 'Sw', 'Crs', 'TI', 'CK', 'In', 'Out',
#        'Str', 'Cmp', 'Off', 'Blocks'],
#       dtype='object')

# %%
# Establecer "Round" como el índice
pass_types.set_index('Round', inplace=True)

# %%
pass_types.head()
# Out:
#              Att  Live  Dead  FK  TB  Sw  Crs  TI  CK  In  Out  Str  Cmp  Off  \
# Round
# Matchweek 1  740   703    36  10   7   1   15  13   5   0    4    0  655    1
# Matchweek 2  714   671    42  15   4   4    7  19   3   1    0    0  632    1
# Matchweek 3  793   752    39   8   3   4   35  11  12   6    2    0  707    2
# Matchweek 4  766   722    43  12   4   3    9  21   4   0    3    0  681    1
# Matchweek 5  747   712    35   7   4   2   25  13  11   0    6    0  676    0
#
#              Blocks
# Round
# Matchweek 1       7
# Matchweek 2       4
# Matchweek 3       9
# Matchweek 4      11
# Matchweek 5      10

# %%
#Scrapeo Tabla de Posesión del Man.City
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'c9/possession/' in l]

# %%
data = requests.get(f"https://fbref.com{links[0]}")
possession = pd.read_html(data.text, match="Possession")[0]
time.sleep(1)
# Out:
# C:\Windows\Temp\ipykernel_18416\3595646561.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   possession = pd.read_html(data.text, match="Possession")[0]

# %%
possession.columns = possession.columns.droplevel()

# %%
possession = possession.drop(columns=columns_to_drop)

# %%
# Establecer "Round" como el índice
possession.set_index('Round', inplace=True)

# %%
possession.columns
# Out:
# Index(['Round', 'Poss', 'Touches', 'Def Pen', 'Def 3rd', 'Mid 3rd', 'Att 3rd',
#        'Att Pen', 'Live', 'Att', 'Succ', 'Succ%', 'Tkld', 'Tkld%', 'Carries',
#        'TotDist', 'PrgDist', 'PrgC', '1/3', 'CPA', 'Mis', 'Dis', 'Rec',
#        'PrgR'],
#       dtype='object')

# %%
possession.head()
# Out:
#              Poss  Touches  Def Pen  Def 3rd  Mid 3rd  Att 3rd  Att Pen  Live  \
# Round
# Matchweek 1  65.0      835       75      267      412      158       23   835
# Matchweek 2  59.0      788       65      212      411      174       21   788
# Matchweek 3  79.0      893       40      153      440      304       53   892
# Matchweek 4  68.0      838       64      222      483      138       20   837
# Matchweek 5  68.0      837       49      148      382      311       49   837
#
#              Att  Succ  ...  Carries  TotDist  PrgDist  PrgC  1/3  CPA  Mis  \
# Round                   ...
# Matchweek 1   10     3  ...      558     2724     1240    12   13    3    9
# Matchweek 2   19    14  ...      434     2418     1223    25   16    9   11
# Matchweek 3   17     9  ...      676     3919     2285    42   40   10   13
# Matchweek 4   17    12  ...      524     2539     1472    18   10    3    9
# Matchweek 5   15     7  ...      678     3574     2229    53   27   15    9
#
#              Dis  Rec  PrgR
# Round
# Matchweek 1    9  632    28
# Matchweek 2    5  627    42
# Matchweek 3    5  700    73
# Matchweek 4    7  673    38
# Matchweek 5    7  670    74
#
# [5 rows x 23 columns]

# %%
passing_stats = pd.merge(passing, pass_types, on='Round', how='inner')

# %%
passing_stats = pd.merge(passing_stats, possession, on='Round', how='inner')

# %%
passing_stats.head()
# Out:
#              Total_Cmp  Total_Att  Total_Cmp%  TotDist_x  PrgDist_x  \
# Round
# Matchweek 1        655        740        88.5      10790       3194
# Matchweek 2        632        714        88.5      10155       2989
# Matchweek 3        707        793        89.2      12243       3342
# Matchweek 4        681        766        88.9      11763       3078
# Matchweek 5        676        747        90.5      10979       2860
#
#              Short_Cmp  Short_Att  Short_Cmp%  Medium_Cmp  Medium_Att  ...  \
# Round                                                                  ...
# Matchweek 1        325        339        95.9         252         277  ...
# Matchweek 2        343        366        93.7         234         263  ...
# Matchweek 3        311        326        95.4         326         352  ...
# Matchweek 4        305        329        92.7         288         311  ...
# Matchweek 5        337        359        93.9         280         301  ...
#
#              Carries  TotDist_y  PrgDist_y  PrgC  1/3_y  CPA  Mis  Dis  Rec  \
# Round
# Matchweek 1      558       2724       1240    12     13    3    9    9  632
# Matchweek 2      434       2418       1223    25     16    9   11    5  627
# Matchweek 3      676       3919       2285    42     40   10   13    5  700
# Matchweek 4      524       2539       1472    18     10    3    9    7  673
# Matchweek 5      678       3574       2229    53     27   15    9    7  670
#
#              PrgR
# Round
# Matchweek 1    28
# Matchweek 2    42
# Matchweek 3    73
# Matchweek 4    38
# Matchweek 5    74
#
# [5 rows x 60 columns]

# %%
passing_stats.to_csv("passing_stats.csv")
